# %% [markdown]
# # csv(comma seprated values)

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\USER\ML_UDAY numpy practice\pandas python

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",nrows=20)
df
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",usecols=[2,4,7])
df
# Out:
#        Rating          Size Price
# 0         4.1  19000.000000     0
# 1         3.9  14000.000000     0
# 2         4.7   8700.000000     0
# 3         4.5  25000.000000     0
# 4         4.3   2800.000000     0
# ...       ...           ...   ...
# 10836     4.5  53000.000000     0
# 10837     5.0   3600.000000     0
# 10838     NaN   9500.000000     0
# 10839     4.5  21516.529524     0
# 10840     4.5  19000.000000     0
#
# [10841 rows x 3 columns]

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",skiprows=2)
df
# Out:
#                                      Coloring book moana       ART_AND_DESIGN  \
# 0      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 1                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 2                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 3                             Paper flowers instructions       ART_AND_DESIGN
# 4                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",skiprows=2)
df
# Out:
#                                      Coloring book moana       ART_AND_DESIGN  \
# 0      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 1                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 2                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 3                             Paper flowers instructions       ART_AND_DESIGN
# 4                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head() #print top 5 data
# Out:
#                                  Coloring book moana  ART_AND_DESIGN  3.9  \
# 0  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  4.7
# 1                              Sketch - Draw & Paint  ART_AND_DESIGN  4.5
# 2              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  4.3
# 3                         Paper flowers instructions  ART_AND_DESIGN  4.4
# 4            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN  3.8
#
#       967  14000.0     500,000+  Free  0  Everyone Art & Design;Pretend Play  \
# 0   87510   8700.0   5,000,000+  Free  0  Everyone              Art & Design
# 1  215644  25000.0  50,000,000+  Free  0      Teen              Art & Design
# 2     967   2800.0     100,000+  Free  0  Everyone   Art & Design;Creativity
# 3     167   5600.0      50,000+  Free  0  Everyone              Art & Design
# 4     178  19000.0      50,000+  Free  0  Everyone              Art & Design
#
#   January 15, 2018               2.0.0  4.0.3 and up
# ...

# %%
df.head(1)
# Out:
#                                  Coloring book moana  ART_AND_DESIGN  3.9  \
# 0  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  4.7
#
#      967  14000.0    500,000+  Free  0  Everyone Art & Design;Pretend Play  \
# 0  87510   8700.0  5,000,000+  Free  0  Everyone              Art & Design
#
#   January 15, 2018  2.0.0  4.0.3 and up
# 0   August 1, 2018  1.2.4  4.0.3 and up

# %%
df.head(8)
# Out:
#                                  Coloring book moana  ART_AND_DESIGN  3.9  \
# 0  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  4.7
# 1                              Sketch - Draw & Paint  ART_AND_DESIGN  4.5
# 2              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  4.3
# 3                         Paper flowers instructions  ART_AND_DESIGN  4.4
# 4            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN  3.8
# 5                                   Infinite Painter  ART_AND_DESIGN  4.1
# 6                               Garden Coloring Book  ART_AND_DESIGN  4.4
# 7                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN  4.7
#
#       967  14000.0     500,000+  Free  0  Everyone Art & Design;Pretend Play  \
# 0   87510   8700.0   5,000,000+  Free  0  Everyone              Art & Design
# 1  215644  25000.0  50,000,000+  Free  0      Teen              Art & Design
# ...

# %%
df.tail()
# Out:
#                                  Coloring book moana       ART_AND_DESIGN  \
# 10834                               Sya9a Maroc - FR               FAMILY
# 10835               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                         Parkinson Exercices FR              MEDICAL
# 10837                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        3.9     967       14000.0     500,000+  Free  0    Everyone  \
# 10834  4.5      38  53000.000000       5,000+  Free  0    Everyone
# 10835  5.0       4   3600.000000         100+  Free  0    Everyone
# 10836  NaN       3   9500.000000       1,000+  Free  0    Everyone
# 10837  4.5     114  21516.529524       1,000+  Free  0  Mature 17+
# 10838  4.5  398307  19000.000000  10,000,000+  Free  0    Everyone
#
#       Art & Design;Pretend Play  January 15, 2018               2.0.0  \
# ...

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",dtype={'id':'float64'})
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",dtype={'id':'float64','size':'float64'})
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",na_values='not available')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 1487

# %%
df.dropna()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dropna(axis=1)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dropna(how='any')
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dropna(axis=1,how='any')
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dropna(how='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.dropna(how='all')
#
# NameError: name 'df' is not defined
